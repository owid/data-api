# %%
from nbinit import *

# %%
pd.options.display.max_colwidth = 150

# %%
# %sql duckdb:///duck.db

# %%
# %sql meta_tables << select * from meta_tables
# Out:
# Returning data to local variable meta_tables
# /work/data-api/.venv/lib/python3.9/site-packages/sql/run.py:370: SAWarning: Dialect postgresql:psycopg2 will not make use of SQL compilation caching as it does not set the 'supports_statement_cache' attribute to ``True``.  This can have significant performance implications including some performance degradations in comparison to prior SQLAlchemy versions.  Dialect maintainers should seek to set this attribute to True after appropriate development and testing for SQLAlchemy 1.4 caching support.   Alternatively, this attribute may be set to False which will disable this warning. (Background on this error at: https://sqlalche.me/e/14/cprf)
#   result = conn.session.execute(txt, user_namespace)

# %%
meta_tables.shape
# Out:
# (764, 11)

# %%
meta_tables[meta_tables.table.str.contains("energy")]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>table</th>
#       <th>dataset</th>
#       <th>version</th>
#       <th>namespace</th>
#       <th>channel</th>
#       <th>checksum</th>
#       <th>dimensions</th>
#       <th>path</th>
#       <th>format</th>
#       <th>table_db_name</th>
#       <th>is_public</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>23</th>
#       <td>dataset_1087_world_bank_se4all_database__energy_efficiency</td>
#       <td>dataset_1087_world_bank_se4all_database__energy_efficiency</td>
#       <td>None</td>
#       <td>se4all</td>
#       <td>backport</td>
#       <td>576fc3dfba6c22f5706ede842db123cf</td>
# ...

# %%
meta_tables[meta_tables.table.str.contains("energy")].table_db_name[592]
# Out:
# 'backport__owid__latest__dataset_5570_energy_mix_from_bp__2021__dataset_5570_energy_mix_from_bp__2021'

# %%
# %sql meta_variables << select * from meta_variables
# Out:
# Returning data to local variable meta_variables

# %%
meta_variables.shape
# Out:
# (38376, 14)

# %%
meta_variables.table_db_name[0]
# Out:
# 'backport__owid__latest__dataset_1002_incidence_of_managerial_or_professional_jobs_and_collective_bargaining_by_gender__blau_and_kahn__2017__dataset_1002_incidence_of_managerial_or_professional_jobs_and_collective_bargaining_by_gender__blau_and_kahn__2017'

# %%
# %sql select entity_id, value from backport__owid__latest__dataset_1002_incidence_of_managerial_or_professional_jobs_and_collective_bargaining_by_gender__blau_and_kahn__2017__dataset_1002_incidence_of_managerial_or_professional_jobs_and_collective_bargaining_by_gender__blau_and_kahn__2017 limit 10
# Out:
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │ /tmp/ipykernel_627/1430679234.py:1 in <cell line: 1>                                      │
# │                                                                                           │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_627/1430679234.py'                   │
# │                                                                                           │
# │ /work/data-api/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2305 in │
# │ run_line_magic                                                                            │
# │                                                                                           │
# │   2302 │   │   │   if getattr(fn, "needs_local_scope", False):                            │
# │   2303 │   │   │   │   kwargs['local_ns'] = self.get_local_scope(stack_depth)             │
# ...

# %%
# %sql describe backport__owid__latest__dataset_1002_incidence_of_managerial_or_professional_jobs_and_collective_bargaining_by_gender__blau_and_kahn__2017__dataset_1002_incidence_of_managerial_or_professional_jobs_and_collective_bargaining_by_gender__blau_and_kahn__2017
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column_name</th>
#       <th>column_type</th>
#       <th>null</th>
#       <th>key</th>
#       <th>default</th>
#       <th>extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>year</td>
#       <td>UBIGINT</td>
#       <td>YES</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>entity_name</td>
#       <td>entity_name</td>
#       <td>YES</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>entity_id</td>
#       <td>BIGINT</td>
# ...

# %%
# %sql tables << SHOW TABLEs
# Out:
# Returning data to local variable tables

# %%
tables.name[0]
# Out:
# 'backport__owid__latest__dataset_1002_incidence_of_managerial_or_professional_jobs_and_collective_bargaining_by_gender__blau_and_kahn__2017__dataset_1002_incidence_of_managerial_or_professional_jobs_and_collective_bargaining_by_gender__blau_and_kahn__2017'
