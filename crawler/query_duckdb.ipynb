# %%
import duckdb

con = duckdb.connect("../duck.db", read_only=True)

con.execute("PRAGMA table_info('meta_tables');").fetch_df()
# Out:
#     cid           name     type  notnull dflt_value     pk
# 0     0          table  VARCHAR     True        NaN   True
# 1     1        dataset  VARCHAR    False        NaN  False
# 2     2        version  VARCHAR    False        NaN  False
# 3     3      namespace  VARCHAR    False        NaN  False
# 4     4        channel  VARCHAR    False        NaN  False
# 5     5       checksum  VARCHAR    False        NaN  False
# 6     6     dimensions  VARCHAR    False        NaN  False
# 7     7           path  VARCHAR    False        NaN  False
# 8     8         format  VARCHAR    False        NaN  False
# 9     9  table_db_name  VARCHAR    False        NaN  False
# 10   10      is_public  BOOLEAN    False        NaN  False

# %%
q = """
select
    *
from meta_tables
limit 5
"""
con.execute(q).fetch_df()
# Out:
#                                                table  \
# 0  dataset_941_technology_adoption__isard__1942__...
# 1  dataset_916_number_of_polio_cases_per_one_mill...
#
#                                              dataset version namespace  \
# 0  dataset_941_technology_adoption__isard__1942__...     NaN      owid
# 1  dataset_916_number_of_polio_cases_per_one_mill...     NaN      owid
#
#     channel                          checksum  \
# 0  backport  76c24e0b3af5621506abb1cd3971faf0
# 1  backport  f2b93dcc3d4c4e2b9c1b392973f2dabf
#
#                                     dimensions  \
# 0  [year, entity_name, entity_id, entity_code]
# 1  [year, entity_name, entity_id, entity_code]
#
#                                                 path   format  \
# 0  backport/owid/latest/dataset_941_technology_ad...  feather
# 1  backport/owid/latest/dataset_916_number_of_pol...  feather
#
#                                        table_db_name  is_public
# 0  backport__owid__latest__dataset_941_technology...       True
# 1  backport__owid__latest__dataset_916_number_of_...       True

# %%
q = """
select
    *
from meta_variables
limit 5
"""
con.execute(q).fetch_df()
# Out:
#    variable_id                                     short_name  \
# 0        42539                    atm__comin_and_hobijn__2004
# 1        42538   agricultural_tractor__comin_and_hobijn__2004
# 2        42540  aviation_passenger_km__comin_and_hobijn__2004
# 3        42535                            canals__isard__1942
# 4        42542          card_payments__comin_and_hobijn__2004
#
#                                           table_path  \
# 0  backport/owid/latest/dataset_941_technology_ad...
# 1  backport/owid/latest/dataset_941_technology_ad...
# 2  backport/owid/latest/dataset_941_technology_ad...
# 3  backport/owid/latest/dataset_941_technology_ad...
# 4  backport/owid/latest/dataset_941_technology_ad...
#
#                                        table_db_name variable_type  \
# 0  backport__owid__latest__dataset_941_technology...         FLOAT
# 1  backport__owid__latest__dataset_941_technology...        BIGINT
# 2  backport__owid__latest__dataset_941_technology...        BIGINT
# 3  backport__owid__latest__dataset_941_technology...         FLOAT
# 4  backport__owid__latest__dataset_941_technology...        BIGINT
#
#                                              title  \
# 0                    ATM (Comin and Hobijn (2004))
# 1   Agricultural tractor (Comin and Hobijn (2004))
# 2  Aviation passenger-km (Comin and Hobijn (2004))
# 3                            Canals (Isard (1942))
# 4          Card payments (Comin and Hobijn (2004))
#
#                                          description  \
# 0  Number of electro-mechanical devices that perm...
# 1  Number of wheel and crawler tractors (excl. ga...
# 2  Civil aviation passenger‐km travelled on sched...
# 3          Measures the mileage of completed canals.
# 4  Number of transactions using payment cards at ...
#
#                                              sources  \
# 0  [{"name": "Isard (1942) and others", "descript...
# 1  [{"name": "Isard (1942) and others", "descript...
# 2  [{"name": "Isard (1942) and others", "descript...
# 3  [{"name": "Isard (1942) and others", "descript...
# 4  [{"name": "Isard (1942) and others", "descript...
#
#                                         grapher_meta          unit short_unit  \
# 0  {"id": 42539, "name": "ATM (Comin and Hobijn (...           NaN        NaN
# 1  {"id": 42538, "name": "Agricultural tractor (C...           NaN        NaN
# 2  {"id": 42540, "name": "Aviation passenger-km (...  passenger-km        NaN
# 3  {"id": 42535, "name": "Canals (Isard (1942))",...       mileage        NaN
# 4  {"id": 42542, "name": "Card payments (Comin an...           NaN        NaN
#
#                                         years_values  \
# 0  [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
# 1  [1961, 1962, 1963, 1964, 1965, 1966, 1967, 196...
# 2  [1930, 1931, 1932, 1933, 1934, 1935, 1936, 193...
# 3  [1800, 1803, 1805, 1807, 1809, 1811, 1813, 181...
# 4  [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
#
#                                      entities_values
# 0  {"entity_id": [13], "entity_code": ["USA"], "e...
# 1  {"entity_id": [13], "entity_code": ["USA"], "e...
# 2  {"entity_id": [13], "entity_code": ["USA"], "e...
# 3  {"entity_id": [13], "entity_code": ["USA"], "e...
# 4  {"entity_id": [13], "entity_code": ["USA"], "e...

# %%
table_name = "backport__owid__latest__dataset_941_technology_adoption__isard__1942__and_others__dataset_941_technology_adoption__isard__1942__and_others"
con.execute(f"PRAGMA table_info('{table_name}');").fetch_df()
# Out:
#     cid                                               name         type  \
# 0     0                                               year      UBIGINT
# 1     1                                        entity_name  entity_name
# 2     2                                          entity_id       BIGINT
# 3     3                                        entity_code  entity_code
# 4     4                        atm__comin_and_hobijn__2004        FLOAT
# 5     5       agricultural_tractor__comin_and_hobijn__2004       BIGINT
# 6     6      aviation_passenger_km__comin_and_hobijn__2004       BIGINT
# 7     7                                canals__isard__1942        FLOAT
# 8     8              card_payments__comin_and_hobijn__2004       BIGINT
# 9     9        commercial_vehicles__comin_and_hobijn__2004        FLOAT
# 10   10  credit_and_debit_payments__comin_and_hobijn__2004        FLOAT
# 11   11  crude_steel_production__blast_oxygen_furnaces_...       BIGINT
# 12   12  crude_steel_production__electric_furnaces__com...      INTEGER
# 13   13  diesel_locomotives_in_service__us_census_burea...      INTEGER
# 14   14                  mri_units__comin_and_hobijn__2004      INTEGER
# 15   15                               mail__mitchell__1998       BIGINT
# 16   16                 newspapers__comin_and_hobijn__2004       BIGINT
# 17   17          rail_passenger_km__comin_and_hobijn__2004       BIGINT
# 18   18  retail_locations_accepting_card__comin_and_hob...        FLOAT
# 19   19                      roads__us_census_bureau__2017      INTEGER
# 20   20           steamships__tons__comin_and_hobijn__2004      INTEGER
# 21   21  synthetic__non_cellulosic__fibres__comin_and_h...       BIGINT
# 22   22                          telegrams__mitchell__1998        FLOAT
#
#     notnull dflt_value     pk
# 0     False        NaN  False
# 1     False        NaN  False
# 2     False        NaN  False
# 3     False        NaN  False
# 4     False        NaN  False
# 5     False        NaN  False
# 6     False        NaN  False
# 7     False        NaN  False
# 8     False        NaN  False
# 9     False        NaN  False
# 10    False        NaN  False
# 11    False        NaN  False
# 12    False        NaN  False
# 13    False        NaN  False
# 14    False        NaN  False
# 15    False        NaN  False
# 16    False        NaN  False
# 17    False        NaN  False
# 18    False        NaN  False
# 19    False        NaN  False
# 20    False        NaN  False
# 21    False        NaN  False
# 22    False        NaN  False

# %%
q = f"""
select * from meta_variables
where variable_id = 42539
"""
r = con.execute(q).fetch_df()
r.iloc[0]
# Out:
# short_name                               atm__comin_and_hobijn__2004
# table_path         backport/owid/latest/dataset_941_technology_ad...
# table_db_name      backport__owid__latest__dataset_941_technology...
# variable_type                                                  FLOAT
# years_values       [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
# entities_values    {'entity_id': [13], 'entity_code': ['USA'], 'e...
# title                                  ATM (Comin and Hobijn (2004))
# description        Number of electro-mechanical devices that perm...
# sources            [{'name': 'Isard (1942) and others', 'descript...
# grapher_meta       {'id': 42539, 'name': 'ATM (Comin and Hobijn (...
# variable_id                                                    42539
# unit                                                             NaN
# short_unit                                                       NaN
# Name: 0, dtype: object
